# %%
import re
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# src = open("/content/drive/My Drive/MDSBA/NLP/Assignment3/train.tags.en-fr.en", "r")
# dst = open("/content/drive/My Drive/MDSBA/NLP/Assignment3/train.tags.en-fr.fr", "r")
# out = open("/content/drive/My Drive/MDSBA/NLP/Assignment3/eng-fra.txt", "a")

# src_lines = src.readlines()
# dst_lines = dst.readlines()

# for i in range(len(src_lines)):
#     x = src_lines[i].strip()
#     y = dst_lines[i].strip()

#     condition = re.search(r"<.+>.*<.+>", x) and re.search(r"<.+>.*<.+>", y)

#     if(not condition):
#         out.write("%s\t%s\n"%(x,y))

# src.close()
# dst.close()
# out.close()

# %%
# %matplotlib inline

# %% [markdown]
# Translation with a Sequence to Sequence Network and Attention
# *************************************************************
# **Author**: `Sean Robertson <https://github.com/spro/practical-pytorch>`_
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ::
#
#     [KEY: > input, = target, < output]
#
#     > il est en train de peindre un tableau .
#     = he is painting a picture .
#     < he is painting a picture .
#
#     > pourquoi ne pas essayer ce vin delicieux ?
#     = why not try that delicious wine ?
#     < why not try that delicious wine ?
#
#     > elle n est pas poete mais romanciere .
#     = she is not a poet but a novelist .
#     < she not not a poet but a novelist .
#
#     > vous etes trop maigre .
#     = you re too skinny .
#     < you re all alone .
#
# ... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the `sequence
# to sequence network <http://arxiv.org/abs/1409.3215>`__, in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# To improve upon this model we'll use an `attention
# mechanism <https://arxiv.org/abs/1409.0473>`__, which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -  http://pytorch.org/ For installation instructions
# -  :doc:`/beginner/deep_learning_60min_blitz` to get started with PyTorch in general
# -  :doc:`/beginner/pytorch_with_examples` for a wide and deep overview
# -  :doc:`/beginner/former_torchies_tutorial` if you are former Lua Torch user
#
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <http://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <http://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <http://arxiv.org/abs/1506.05869>`__
#
# You will also find the previous tutorials on
# :doc:`/intermediate/char_rnn_classification_tutorial`
# and :doc:`/intermediate/char_rnn_generation_tutorial`
# helpful as those concepts are very similar to the Encoder and Decoder
# models, respectively.
#
# And for more, read the papers that introduced these topics:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <http://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <http://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <http://arxiv.org/abs/1506.05869>`__
#
#
# **Requirements**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# `This question on Open Data Stack
# Exchange <http://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages>`__
# pointed me to the open translation site http://tatoeba.org/ which has
# downloads available at http://tatoeba.org/eng/downloads - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: http://www.manythings.org/anki/
#
# The English to French pairs are too big to include in the repo, so
# download to ``data/eng-fra.txt`` before continuing. The file is a tab
# separated list of translation pairs:
#
# ::
#
#     I am cold.    J'ai froid.
#
# .. Note::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/data.zip>`_
#    and extract it to the current directory.

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# .. figure:: /_static/img/seq-seq-images/word-encoding.png
#    :alt:

# %% [markdown]
# We'll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called ``Lang`` which has word → index (``word2index``) and index → word
# (``index2word``) dictionaries, as well as a count of each word
# ``word2count`` to use to later replace rare words.

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. The files are all English → Other Language, so if we
# want to translate from Other Language → English I added the ``reverse``
# flag to reverse the pairs.

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('/content/drive/My Drive/MDSBA/NLP/Assignment3/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)
    print(input_lang, output_lang, pairs)
    return input_lang, output_lang, pairs

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we'll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we're filtering to sentences that translate to
# the form "I am" or "He is" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -  Read text file and split into lines, split lines into pairs
# -  Normalize text, filter by length and content
# -  Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# <__main__.Lang object at 0x7f231cb89470> <__main__.Lang object at 0x7f22ff4dbf98>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Trimmed to 1008 sentence pairs
# Counting words...
# Counted words:
# fra 1663
# eng 1457
# ['je vais sauter jusqu a la .', 'i m going to jump forward here .']

# %%
pairs
# Out:
# [['il fait fonctionner la patte .', 'he s working the leg .'],
#  ['tu es vraiment un gentil petit robot .',
#   'you re such a cute little robot .'],
#  ['apres tout ce ne sont que des machines .',
#   'they re just machines after all .'],
#  ['j observe tres soigneusement vos visages .',
#   'i m watching your faces very carefully .'],
#  ['je ne la ressens pas avec le sourcil .',
#   'i m not getting it off the eyebrow .'],
#  ['je suis vraiment dedans maintenant .',
#   'i m really getting into this now .'],
#  ['nous ne faisons que nous maintenir .',
#   'we re only just holding it together .'],
#  ['je suis une personne independante autonome . ',
#   'i m an independent individual person . '],
#  ['elles nous vendent des chaussures et des voitures .',
#   'they re selling us shoes and cars .'],
#  ['ce n est pas mal du tout .', 'we re in good enough shape .'],
#  ['on n est pas vraiment comme youtube ', 'we re not quite a youtube .'],
#  ['ils sont tres grands .', 'they re very large .'],
#  ['on n aime pas trop le desordre .',
#   'we re very uncomfortable with untidiness .'],
#  ['j essaye de faire ca en anglais .', 'i m trying to do this in english .'],
#  ['desole les techniciens .', 'i m so sorry technicians .'],
#  ['j ai l habitude .', 'i m so used to that .'],
#  ['elle est filmee avec une camera cachee .',
#   'she s being filmed with a hidden camera .'],
#  ['elles sont justes aussi naturelles que les vaches .',
#   'they re just as natural as cows .'],
#  ['elles sont une sorte d ectosymbionte .',
#   'they re a sort of ectosymbiont .'],
#  ['je vais parler de brebis aussi .', 'i m going to talk about sheep too .'],
#  ['je parle aussi de la chretiente .',
#   'i m talking also about christianity .'],
#  ['il a absolument raison .', 'he s absolutely right .'],
#  ['vous devez les imaginer .', 'you re having to imagine it .'],
#  [' nous te sponsorisons mon gars .', 'we re like we re sponsoring you man .'],
#  ['tu es un pro . ', 'you re like a pro maker . '],
#  ['nous sommes dans une position de danger .',
#   'we are in a position of danger .'],
#  ['je suis une artiste nomade .', 'i am a nomadic artist .'],
#  ['elle ajouta etait il atteint lui aussi ? ',
#   'she said did he have them himself ? '],
#  ['vous etes a un certain carrefour .',
#   'you re at a particular road junction .'],
#  ['il y a des choses comme celle ci .', 'they re things like this .'],
#  ['nous parlons a quelque chose .', 'we re talking to something .'],
#  ['il y reflechit .', 'he s thinking about it .'],
#  ['nous faisons deux choses differentes ici .',
#   'we re doing two different things here .'],
#  ['nous sommes maintenant en direct de caracas',
#   'we are going live now to caracas .'],
#  ['les ecrans tactiles m interessent beaucoup',
#   'i m very interested in touch sensitive displays .'],
#  ['nous sommes tellement habitues a monologuer .',
#   'we are so used to doing monologues .'],
#  ['nous sommes obnubiles par cette facon de penser .',
#   'we are obsessed with this way of thinking .'],
#  ['je vais vous parler de secrets .',
#   'i am going to be talking about secrets .'],
#  ['ils sont si differents .', 'they are so different .'],
#  ['il est un peu comme un spiderman aquatique .',
#   'he s like an underwater spiderman .'],
#  ['je vais dessiner ce poisson globe degonfle .',
#   'i m going to draw this blowfish uninflated .'],
#  ['c est un grand requin blanc .', 'he s a great white shark .'],
#  ['je suis enchante d etre ici .', 'i m delighted to be here .'],
#  ['je suis honore de l invitation et merci .',
#   'i m honored by the invitation and thanks .'],
#  ['elles sont dures a comprendre automatiquement .',
#   'they re hard to just get automatically .'],
#  ['je vais vous en parler .', 'i m going to be talking about this .'],
#  ['nous n avons pas encore termine .', 'we re not quite done yet .'],
#  ['je suis conteuse .', 'i m a storyteller .'],
#  ['ils sont vautres dans leur marigot intellectuel',
#   'they are stuck in their intellectual patch .'],
#  ['nous sommes tous dans le meme bateau .', 'we are one .'],
#  ['nous rechauffons le climat .', 'we re warming the climate .'],
#  ['c est une communaute de travailleurs .',
#   'they are very hardworking people .'],
#  ['je suis mon connectome .', 'i am my connectome .'],
#  ['elles seront toutes emmelees .', 'they re going to be scrambled up .'],
#  ['c est elle qui me nourrit .', 'she s the one who feeds me .'],
#  ['nous investissons dans notre futur .', 'we re investing in our future .'],
#  ['nous sommes une nation d immigrants .', 'we are a nation of immigrants .'],
#  ['vous etes vous etes le general powell . ',
#   'you re well you re general powell . '],
#  ['nous ecoutons en fonction de notre culture .',
#   'we re culture bound listeners .'],
#  ['elle a six mois .', 'she s a six monther .'],
#  ['nous voyons le cerveau du bebe .', 'we re seeing the baby brain .'],
#  ['ce n est pas un luxe .', 'they are not luxuries .'],
#  ['il emprunte le sentier .', 'he s going down the path .'],
#  ['vous applaudissez pour cela ?', 'we re clapping for that ?'],
#  ['nous crochetons un recif de corail .', 'we re crocheting a coral reef .'],
#  ['je vais proposer une reponse .', 'i m going to answer that question .'],
#  ['c est un bonobo .', 'he s a bonobo .'],
#  [' video tu es content .', 'you re happy .'],
#  ['tu es tres content de cette partie .',
#   'you re very happy about this part .'],
#  ['nous apprenons a devenir comme eux .',
#   'we re learning how to become like them .'],
#  ['ce sont les juifs irakiens d aujourd hui .',
#   'they re today s iraqi jews .'],
#  ['j irais construire des lunettes google .',
#   'i m going off to build google glass .'],
#  ['elles se choregraphient elles memes .',
#   'they re choreographing themselves .'],
#  ['elles vous gardent en vie .', 'they re keeping you alive .'],
#  ['ils ont tous des difficultes a marcher .',
#   'they re all having some difficulty walking .'],
#  ['je suis un immigre numerique .', 'i m a digital immigrant .'],
#  ['je suis le specialiste jeux pour discover magazine .',
#   'i m the puzzle columnist for discover magazine .'],
#  ['elle a change les regles .', 'she s changed the rules .'],
#  ['je suis une creature emotionnelle ! ', 'i m an emotional creature ! '],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis une creature emotionnelle .', 'i am an emotional creature .'],
#  ['je suis ta memoire restante .', 'i am your remaining memory .'],
#  ['je vous propose trois directives .', 'i m proposing three planks .'],
#  ['nous nous posons toujours la question .',
#   'we are still asking the question .'],
#  ['on va maintenant les allumer .', 'we re now going to turn it on .'],
#  ['elle commence a reculer .', 'she starts leaning back .'],
#  ['ils ne bougent pas .', 'they re just not moving .'],
#  ['elles foisonnent d informations .', 'they re packed with information .'],
#  ['on ne fonctionne plus si facilement qu autrefois .',
#   'we aren t functioning so easily anymore .'],
#  ['nous ne sommes plus un simple regime autoritaire .',
#   'we aren t a simple authoritarian regime anymore .'],
#  ['je suis un fier etudiant ayant quitte princeton .',
#   'i am a proud princeton dropout .'],
#  ['nous prenons le vent des deux cotes .',
#   'we re catching wind from both sides .'],
#  ['c est un architecte et designer espagnol .',
#   'he s a spanish architect and designer .'],
#  ['elle a dit oh je l aime . ', 'she said oh i love it . '],
#  ['ils vont voir eddy a lagos .', 'they re going to eddy in lagos .'],
#  ['et elle repond j ai ans . ', 'she says i m . '],
#  ['je suis serieuse .', 'i m serious .'],
#  ['nous recherchons trois filles .', 'we re looking for three girls .'],
#  ['tzvika je suis le directeur ici .', 'i am the headmaster for all parts .'],
#  ['elles sont identiques en tout point .',
#   'they are identical in every single way .'],
#  ['ce sont les meme . d accord ?', 'they are the same . okay ?'],
#  ['nous sommes aussi une espece de conteurs .',
#   'we re also a species of storytellers .'],
#  ['nous sommes vraiment bons avec les petits chiffres .',
#   'we re really good at small numbers .'],
#  ['et je vais apporter une complication supplementaire .',
#   'i m going to give one more complication .'],
#  ['elles sont menacees a cause du changement climatique .',
#   'they re under threat because of changing climate .'],
#  ['on apprend a ces enfants la temperance .',
#   'they are teaching these kids exactly this principle .'],
#  ['nous voyons des nouveaux signes .', 'we are seeing some new signs .'],
#  ['elle dit oh c est superbe .', 'she says oh that s beautiful .'],
#  ['il a un excelent chapitre la dessus .',
#   'he s got a great chapter about it .'],
#  ['vous etes tous membres de tribus .', 'you re all a member of tribes .'],
#  ['je suis super pas vous .', 'i m great and you re not .'],
#  ['je vais vous lire quelques histoires .',
#   'i m going to read a few strips .'],
#  ['nous sommes ici pour celebrer la compassion .',
#   'we re here to celebrate compassion .'],
#  ['je pensais d accord .', 'i m going ok you know . fine .'],
#  ['vous n etes pas un canard .', 'you re not a duck .'],
#  ['je ne fais pas attention a eux .', 'they re not on my radar .'],
#  ['nous depensons milliards de dollars pour ce recensement .',
#   'we re spending billion dollars on the census .'],
#  ['elles ont pour sujet la demographie .', 'they re about demographics .'],
#  ['nous ne nous interessons pas aux metriques significatives .',
#   'we re not asking meaningful metrics .'],
#  ['nous ne posons pas les questions importantes .',
#   'we re not asking important questions .'],
#  ['nous ne demandons rien qui soit intangible .',
#   'we re not asking anything that s intangible .'],
#  ['elles ne sont pas identiques .', 'they aren t the same .'],
#  ['je cherchais un remede .', 'i m looking for a cure .'],
#  ['ils sont exotiques . ils sont experimentaux .',
#   'they re exotic . they re experimental .'],
#  ['ils sont dans le deni .', 'they re in denial .'],
#  ['ils chantent .', 'they re singing .'],
#  ['vous le publiez .', 'you re publishing it .'],
#  ['je suis desole de vous le dire .', 'i m sorry to say that .'],
#  ['elle est en train d etre baptisee .', 'she s being baptized .'],
#  ['ce sont simplement des icones vous cliquez dessus .',
#   'they re just icons you click on them .'],
#  ['vous avez tort .', 'you re wrong .'],
#  ['ils sont tous montes sur mes instruments .',
#   'they re all mounted on my instruments .'],
#  ['je suis une multitude .', 'i am multitudes .'],
#  ['ils apprennent tout juste a compter .',
#   'they re just learning how to count .'],
#  ['ce sont des visualisations graphiques d un personnage .',
#   'they are a graphical visualization of a character .'],
#  ['et moi eh petit je suis hindou . ', 'i m like dude i m hindu . '],
#  ['et lui hah ! ', 'he s like huh ! '],
#  ['je vous dis il est la !', 'i m telling you it s there !'],
#  ['nous sommes assez efficaces dans les secteurs industriels .',
#   'we re reasonably efficient in the industrial sectors .'],
#  ['j en ai aussi un peu peur .', 'i m also slightly in awe of them .'],
#  ['nous ne sommes la que pour le decor .',
#   'we are for decorative purposes only .'],
#  ['nous sommes tres habitues a cela .', 'we re very used to this .'],
#  ['la femme de rien .', 'you re most welcome .'],
#  ['j adore les villes .', 'i m a big fan of cities .'],
#  ['nous nous heurtons constamment les uns les autres .',
#   'we re constantly running into each other .'],
#  ['nous essayons de reduire la population carcerale .',
#   'we re trying to reduce the prison population .'],
#  ['vous etes une personne formidable .', 'you re an inspiring person .'],
#  ['je n ai rien contre la technologie .', 'i am not a luddite .'],
#  ['nous perdons un rituel .', 'we re losing a ritual .'],
#  ['elle dit c etait bien . ', 'she says it was good . '],
#  ['elle dit oui . ', 'she says i did . '],
#  ['ils parlent de la transformation .', 'they re all about transformation .'],
#  ['tu vas tous nous sauver ! ', 'you re going to save us all ! '],
#  ['il vous chuchote a l oreille .', 'he s whispering into your ears .'],
#  ['nous sommes une ame .', 'we are a soul .'],
#  ['je suis l incarnation de toute verite . ',
#   'i m the embodiment of all truth . '],
#  ['ils sont detruits .', 'they are crushed .'],
#  ['elle a dit c est wei .', 'she said that s wei .'],
#  ['elle est tres athletique .', 'she s highly athletic .'],
#  ['il n est plus en fonction aujourd hui .', 'he s out of office today .'],
#  ['je parle de toutes les entreprises .', 'i m talking about all companies .'],
#  ['je suis le mexicain de la famille .', 'i m the mexican in the family .'],
#  ['l argent ne nous interesse pas .', 'we are not interested in money .'],
#  ['et ils vont etre petits .', 'they re going to be small .'],
#  ['il est desormais general une etoile .', 'he s now a one star general .'],
#  ['vous etes l amerique . ', 'you re america . '],
#  ['prenez les annees .', 'i m talking about the s .'],
#  ['on en a fini avec ca .', 'we re done with that .'],
#  ['je presente les informations a six heures . ',
#   'i m reading the news at six . '],
#  ['nous sommes uniques . nous sommes irremplacables .',
#   'we are unique . we are irreplaceable .'],
#  ['elle est aussi immensement pragmatique .',
#   'she is also immensely pragmatic .'],
#  ['nous allons manquer d eau .', 'we re running out of fresh water .'],
#  ['nous allons manquer de combustibles fossiles .',
#   'we re running out of fossil fuels .'],
#  ['nous allons manquer de terres .', 'we re running out of land .'],
#  ['vous etes apeures de poursuivre votre passion .',
#   'you re afraid to pursue your passion .'],
#  ['vous avez peur d avoir l air ridicule .',
#   'you re afraid to look ridiculous .'],
#  ['je ne suis pas radiologue .', 'i m not a radiologist .'],
#  ['nous sommes les nouveaux technologues .', 'we re the new technologists .'],
#  ['vous etes hors de danger c est bon .', 'you re safe . it s fine .'],
#  ['nous vivons dans un monde de chiffres .',
#   'we re numbers people living by numbers .'],
#  ['nous sommes ceux qui ecrivent cet opera .',
#   'we re the ones writing this opera .'],
#  ['je vais vous donner un exemple .', 'i m going to give you some example .'],
#  ['ce sont des entrepreneurs .', 'they are the entrepreneurs .'],
#  ['les gens viendront dans votre quartier .',
#   'they re going to come into your neighborhood .'],
#  ['je suis la petite .', 'i m the short one .'],
#  ['ils sont emotionnels . ils sont conscients .',
#   'they re emotional . they re aware .'],
#  ['nous ne sommes pas seuls .', 'we are not alone .'],
#  ['nous ne sommes pas seuls avec ces capacites .',
#   'we are not alone in these abilities .'],
#  ['ils sont accessibles par cet ascenseur en diagonale .',
#   'they are accessed through this diagonal elevator .'],
#  ['je suis tout a fait pour .', 'i m all for that .'],
#  ['elle commenca la confection .', 'she started tailoring .'],
#  ['personne .', 'they re not . '],
#  ['je vais parler de ca rapidement .',
#   'i m going to quickly go through this .'],
#  ['vous etes le maire de votre ville .',
#   'you re the mayor of your local town .'],
#  ['je pense que cela devrait etre instantane .', 'i m thinking dipstick .'],
#  ['il est impossible de jongler avec . ', 'they are impossible to juggle . '],
#  ['nous en sommes fiers .', 'we are proud of it .'],
#  ['il a invite tous les gens super .', 'he s invited all the best people .'],
#  ['c est le gourou dietetique de la television .',
#   'she is our tv diet guru .'],
#  ['vous etes arabe musulman vivant en irak .',
#   'you re arab muslim living in iraq .'],
#  ['ils sont chretiens .', 'they re christians .'],
#  ['ce sont mes eleves mes amis .', 'they re my students my friends .'],
#  ['vous generalisez . c est faux .', 'you re generalizing . it s wrong .'],
#  ['elle est n importe qui pour moi .', 'she s anybody to me .'],
#  ['vous avez le droit de hair ces gens .',
#   'you re allowed to hate these people .'],
#  ['nous concevons des environnements qui nous rendent dingues .',
#   'we re designing environments that make us crazy .'],
#  ['je suis force de me poser la question .',
#   'i am forced to ask myself a question .'],
#  ['je suis fort je suis puissant .', 'i am powerful and i am strong .'],
#  ['nous sommes nes pour faire la difference .',
#   'we re born to make a difference .'],
#  ['je ne vais pas aller jusqu a .', 'i m not going to get to .'],
#  ['elle vend du chocolat .', 'she sells chocolates .'],
#  ['nous ne sommes pas un groupe d interet .',
#   'we are not a special interest group .'],
#  ['nous sommes la majorite .', 'we are the majority .'],
#  ['elle m a dit regarde qui c est .', 'she said look who she is .'],
#  ['vraiment .', 'they are .'],
#  ['en fait vous faconnez un etre humain ici .',
#   'you re actually sculpting a human being here .'],
#  ['nous lui apprenons vraiment .', 'we re actually teaching him .'],
#  ['ils stressent tout le temps .', 'they re always getting stressed .'],
#  ['elle partage avec d autres ses experiences .',
#   'she shares her experience with others .'],
#  ['je suis un medecin redefini .', 'i am a redefined physician .'],
#  ['je suis humain . je fais des erreurs .', 'i m human . i make mistakes .'],
#  ['maintenant on en enregistre un millier .', 'we are doing a thousand now .'],
#  ['elle envoyait de l argent a sa famille .',
#   'she sent money back to her family .'],
#  ['elle exagere . ', 'she s exaggerating . '],
#  ['ils sont beaucoup plus rapproches que ca . ',
#   'they re far closer together than that . '],
#  ['nous accompagnons voyager .', 'we re now riding along with voyager .'],
#  ['nous sommes aussi nes en quete de plaisir .',
#   'we re also born pleasure seekers .'],
#  ['nous sommes des etres sociaux des le debut .',
#   'we are social beings from the beginning .'],
#  ['on parle de la .', 'we re talking now .'],
#  ['ils sont extremement sensibles aux odeurs .',
#   'they re extremely sensitive to smell .'],
#  ['ici nous voyons des neurones .', 'we re looking at neurons here .'],
#  ['je vais vous dire pourquoi .', 'i m going to tell you why .'],
#  ['nous faisons baisser la courbe .', 'we are bending the curve .'],
#  ['nous faisons baisser la courbe .', 'we re bending the curve .'],
#  ['il laisse de l encre rouge derriere lui .',
#   'he s leaving red ink behind .'],
#  ['tu ne fais pas parti du beau monde .',
#   'you re not one of the beautiful people .'],
#  ['on est dans une mauvaise passe .', 'we re in trouble .'],
#  ['c est un homme vraiment remarquable .',
#   'he s a very very remarkable man .'],
#  ['il est meme ici aujourd hui .', 'he s even here today .'],
#  ['nous n essayons pas de controler la polio .',
#   'we re not trying to control polio .'],
#  ['ce seront les plus resistants .', 'they re going to be the tough ones .'],
#  ['ils sont essentiels pour l habitat .',
#   'they re essential to the habitat .'],
#  ['il est une passerelle .', 'he is a bridge figure .'],
#  ['ils sont plus americains qu autre chose .',
#   'they are more american than anything else .'],
#  ['il est a taiwan actuellement .', 'he s in taiwan right now .'],
#  ['elle m a dit ah bon ?', 'she s like it s not ?'],
#  ['je suis ravi d etre ici .', 'i m thrilled to be here .'],
#  ['il en reve encore .', 'he s still dreaming about it .'],
#  ['nous sommes un noyau social .', 'we are social to the core .'],
#  ['vous regardez une video .', 'you re watching a video .'],
#  ['je vais probablement sauter .', 'i m probably going to jump .'],
#  ['vous allez toucher le sol .', 'you are going to hit the ground .'],
#  ['ils essaient de faire des multiplications je crois .',
#   'they are trying to multiply i think .'],
#  ['je suis en pleine epreuve actuellement .',
#   'i m in the crucible right now .'],
#  ['nous essayons toujours de la rendre plus rapide .',
#   'we re always trying to make it faster .'],
#  ['ils sont en joint venture avec sumitomo .',
#   'they re in a joint venture with sumitomo .'],
#  ['nous sommes ok go .', 'we are ok go .'],
#  ['nous apprenons tous par la pratique .', 'we re all learning by doing .'],
#  ['je suis essentiellement un philosophe de la morale .',
#   'i m primarily a moral philosopher .'],
#  ['ce ne sont que des m urs heritees .', 'they re just inherited mores .'],
#  ['j ai beaucoup de chance d etre ici .', 'i m very fortunate to be here .'],
#  ['je ne suis pas tout seul .', 'i m not here alone .'],
#  ['je ne fais que surveiller le temps .', 'i m just a clock watcher .'],
#  ['ce sont les adversaires les plus coriaces .',
#   'they are the toughest opponents .'],
#  ['il a participe a nombreuses batailles .', 'he s been in many battles .'],
#  ['c est non seulement possible c est crucial .',
#   'they re not just possible they re critical .'],
#  ['je ne cherche pas un correspondant .', 'i m not looking for a pen pal .'],
#  ['je cherche un mari d accord ?', 'i m looking for a husband . right ?'],
#  ['on les appelle des automates cellulaires .',
#   'they re called cellular automata .'],
#  ['elle est battue .', 'she s beaten .'],
#  ['vous etes tellement passionnes .',
#   'you are somebody who is so passionate .'],
#  ['j appelle cela la grande decompression',
#   'i m calling this the great unwind .'],
#  ['ils prennent la responsabilite .', 'they are taking responsibility .'],
#  ['nous allons expliquer ca maintenant .',
#   'we re going to explain that right now .'],
#  ['j avoue mon manque d assurance .', 'i m telling you where i m insecure .'],
#  ['je suis une conteuse .', 'i m a storyteller .'],
#  ['ce concept m intrigue .', 'i m intrigued by this concept .'],
#  ['on va commencer en .', 'we re going to begin in .'],
#  ['on nous observe .', 'we are being watched .'],
#  ['ils sont retournes a philadelphie .', 'they re back in philadelphia .'],
#  ['ce sont des objets de desir .', 'they are objects of desire .'],
#  ['ce sont des instruments de musique imaginaires .',
#   'they are imaginary musical instruments .'],
#  ['je suis un concepteur et un educateur .',
#   'i m a designer and an educator .'],
#  ['ils ne construisent pas de transmetteurs .',
#   'they re not building transmitters .'],
#  ['nous ne sommes pas un miracle d accord ?', 'we re not a miracle okay ?'],
#  ['nous parlons de la haute mer .', 'we are talking about the high seas .'],
#  ['il travaille au mit .', 'he s at mit .'],
#  ['ils ne sont pas statistiquement significatifs .',
#   'they re not statistically significant .'],
#  ['nous ne ralentissons meme pas .', 'we re not even slowing down .'],
#  ['ils ont tort .', 'they re wrong .'],
#  ['et de nouvelles dents repoussent .', 'you re grow a set of teeth .'],
#  ['maintenant elle court avec ses enfants .',
#   'she s now running around with her kids .'],
#  ['tout passera par la machine .', 'they re going through the machine .'],
#  ['ils parleront le langage du web .',
#   'they re going to speak the web language .'],
#  ['ils parleront a la machine .', 'they re going to talk to the machine .'],
#  ['nous allons etre la machine .', 'we are going to be the machine .'],
#  ['nous commencons a explorer l interieur du cerveau .',
#   'we re beginning to look inside the brain .'],
#  ['c est totalement incroyable .', 'they re just totally incredible .'],
#  ['ils sont biologiquement incompatibles .',
#   'they re not biologically compatible .'],
#  ['vous etes contents et vous fetez ca .', 'you re done and you celebrate .'],
#  ['elle est tres soutenue par son entourage .',
#   'she s in a very supportive environment .'],
#  ['ils sont opprimes .', 'they are oppressed .'],
#  ['elles sont la cause de beaucoup de detresse .',
#   'they are the cause of much distress .'],
#  ['nous allons fusionner avec notre technologie .',
#   'we are going to merge with our technology .'],
#  ['on me presente souvent comme un explorateur polaire .',
#   'i m usually introduced as a polar explorer .'],
#  ['vous gagnez x par truc .', 'you re making x amount per widget .'],
#  ['je vais donner bebe a mamie .', 'i m going to give bebko to baba .'],
#  ['je vais encourager la critique constructive .',
#   'i m going to encourage constructive criticism .'],
#  ['je vais vous laisser defier l autorite .',
#   'i m going to let you challenge authority .'],
#  ['nous allons eradiquer la peur .', 'we re going to eradicate fear .'],
#  ['je vais commencer par glenn gould .',
#   'i m going to start with glenn gould .'],
#  ['nous sommes au pouvoir . c est effrayant .',
#   'we re in charge . it s frightening .'],
#  ['j ai vraiment de la chance .', 'i m really fortunate .'],
#  ['ce sont essentiellement des cameras digitales .',
#   'they re essentially digital cameras .'],
#  ['ils interagissent avec le champ de higgs .',
#   'they re interacting with the higgs field .'],
#  ['je suis content que vous reconnaissiez margaret thatcher .',
#   'i m glad you recognize margaret thatcher .'],
#  ['tous deux sont des histoires des interpretations .',
#   'they re both stories interpretations .'],
#  ['il est professeur au mit .', 'he s a professor at mit .'],
#  ['ils ne sont meme pas autonomes .', 'they re not even autonomous .'],
#  ['ils surveillent la position de leurs voisins .',
#   'they re monitoring their neighbors position .'],
#  ['ils maintiennent la formation .', 'they re maintaining formation .'],
#  ['je ne suis pas du tout une cuisiniere .', 'i m not at all a cook .'],
#  [' les enfants eux sont interesses .', 'they are interested .'],
#  ['on travaille dur la dessus .', 'we re still working hard at it .'],
#  ['homme je suis desole .', 'i m sorry .'],
#  ['il est essentiellement un broyeur a pattes .',
#   'he s basically a walking mulch pile .'],
#  [' je suis le chameau ted ', 'i m ted camel .'],
#  [' je suis concu de facon intelligente ', 'i m smartly designed .'],
#  [' je suis construit pour durer ', 'i m built to last .'],
#  [' je suis puissant ', 'i m powerful .'],
#  [' je suis aussi un bon fournisseur . ', 'i m a good provider too .'],
#  ['on t aime pour toi meme .', 'you re loved for just being you .'],
#  ['nous aurons un univers personnel .',
#   'we re going to have a personal universe .'],
#  ['nous sommes un pays de victimes .', 'we are a country of victims .'],
#  ['nous avons tres peur .', 'we re very afraid .'],
#  ['nous sommes face a un adversaire tres puissant .',
#   'we re facing a very powerful opponent .'],
#  ['maintenant je vais augmenter la complexite .',
#   'i m going to build towards complexity now .'],
#  ['il a cree nouveaux emplois .', 'he s made new jobs .'],
#  ['je suis ignostique .', 'i m an ignostic .'],
#  ['nous allons essayer la science . ', 'we re going to try science . '],
#  ['nous sommes en train de perdre l ecoute .',
#   'we are losing our listening .'],
#  ['nous devenons impatients .', 'we re becoming impatient .'],
#  ['nous devenons insensibilises . .', 'we re becoming desensitized .'],
#  ['vous allez prendre les photos .', 'you are going to take the photos .'],
#  ['vous allez me les envoyer .', 'you re going to send them to me .'],
#  ['vous faites constamment des predictions sur votre environnement .',
#   'you re constantly making predictions about your environment .'],
#  ['elle repond dans les aeroports du monde .',
#   'she says the airports of the world .'],
#  ['elle est maintenant candidate a la presidentielle .',
#   'she is now running for president .'],
#  ['ils sont heureux . ils sont satisfaits .',
#   'they re happy . they are satisfied .'],
#  ['ils sont curieux .', 'they are curious .'],
#  ['ils sont aussi une part de ce monde .',
#   'they are also part of this world .'],
#  ['il nous manque la californie a la carte .',
#   'we re missing california from american english .'],
#  ['il a trouve plus de cometes .', 'he s found more than comets .'],
#  ['je suis tres enthousiaste a ce propos .',
#   'i m incredibly excited about that .'],
#  ['ils sont reconstructifs .', 'they re reconstructive .'],
#  ['nous leur faisons une confiance quasi aveugle .',
#   'we re almost blindly reliant on it .'],
#  ['nous faisons un debat .', 'we re having a debate .'],
#  ['sous l appellation de batteries nucleaires .',
#   'they re referred to as nuclear batteries .'],
#  ['on est situe en floride .', 'we re based down in florida .'],
#  ['on recherche un prix orbital .', 'we re going after an orbital prize .'],
#  ['nous vivons un moment remarquable ici .',
#   'we are in a remarkable moment here .'],
#  ['je represente ce phenomene .', 'i m a representation of that phenomenon .'],
#  ['il est assis juste ici .', 'he s sitting there .'],
#  ['nous allons creer deux types differents .',
#   'we re going to make two different kinds .'],
#  ['ils sont delicieux .', 'they re delicious .'],
#  ['elle ne va jamais s en sortir . ', 'she s not going to go anywhere . '],
#  ['on utilise environ cinq planetes .', 'we re using up about five planets .'],
#  ['je commencerai par ceci .', 'i m going to start here .'],
#  ['c est mon donneur .', 'he s my donor .'],
#  ['ils sont partout dans le monde .', 'they re all over the world .'],
#  ['ils explorent les niveaux de densite du sang',
#   'they re mining blood density levels .'],
#  ['observez la fabrication du bonheur .',
#   'you re watching happiness be synthesized .'],
#  ['il vient de floride .', 'he s from florida .'],
#  ['je vais vous raconter celle ci .', 'i m telling you this one .'],
#  ['elle dit maman tu dois regarder ! ', 'she says ma you got to look ! '],
#  ['elle est apres tout cubaine .', 'she is after all cuban .'],
#  ['elle serre le sac a main .', 'she s hugging the purse .'],
#  ['elle me dit ca ', 'she says this to me .'],
#  ['j ai vraiment peur .', 'i m really scared .'],
#  ['je vais vous donner quelques exemples .',
#   'i m going to give you some examples .'],
#  ['ce sont attitude attention et authenticite .',
#   'they are attitude awareness and authenticity .'],
#  ['ils sont au fond de vous .', 'they re in there .'],
#  ['c est le numero sur la photo .', 'he s number in the picture .'],
#  ['ca l interesse de jouer au foot .',
#   'he s interested in playing football .'],
#  ['elle ne plaisante pas du tout . ', 'she s totally not kidding . '],
#  ['nous n utilisons pas d energies fossiles .',
#   'we are not using fossil energies .'],
#  ['ils sont une sorte de capital social .',
#   'they are a kind of social capital .'],
#  ['ils s entre tuent .', 'they re killing each other .'],
#  ['nous travaillons avec des supports qui changent .',
#   'we re doing changing media .'],
#  ['elles sont commandees', 'they are commissioned .'],
#  ['je rigole !', 'i m joking yeah ?'],
#  ['vous etes en train de regarder .', 'you re peeking .'],
#  ['je dis s il te plait explose . ', 'i m saying please blow up . '],
#  ['il dirige mozart .', 'he s conducting mozart .'],
#  ['ce sont toutes des possibilites importantes . ',
#   'they re all important choices . '],
#  ['on les perd .', 'we re losing them .'],
#  ['nous sommes tous nes artistes .', 'we are all born artists .'],
#  ['ils sont sous le choc .', 'they re shocked .'],
#  ['ce sont des demons . des demons .', 'they are devils . devils .'],
#  ['il sont si fragiles .', 'they re just so so delicate .'],
#  ['je suis sur que nous en trouverons un .',
#   'i m confident that we ll find one .'],
#  ['on ne vous invite pas .', 'you re not asked .'],
#  ['je m appelle jessi et voici ma valise .',
#   'i m jessi and this is my suitcase .'],
#  ['ils se depassent vraiment .', 'they are really excelling .'],
#  ['il va a l ecole maternelle .', 'he s in kindergarten .'],
#  ['vous etes un pre vivant .', 'you are a pre vivor .'],
#  ['nous sommes tous responsables .', 'we are all responsible .'],
#  ['je suis responsable .', 'i m responsible .'],
#  ['ils sont tres travailleurs .', 'they re super industrious .'],
#  ['vous etes des gens paisibles .', 'you are peaceful people .'],
#  ['nous sommes a un point de basculement .',
#   'we re in a tipping point moment .'],
#  ['elle a ans .', 'she s years old .'],
#  ['il n en peut plus .', 'he s sick of it .'],
#  ['nous ne sommes pas equipes pour faire ceci .',
#   'we re not geared up to do this .'],
#  ['je ne les critique pas .', 'i m not slagging them off .'],
#  ['elles font du mieux qu elles peuvent .',
#   'they re doing the best they can do .'],
#  ['elles font de leur mieux .', 'they re doing their best .'],
#  ['nous n enseignons pas a nos enfants .', 'we re not teaching our kids .'],
#  ['je suis la .', 'i m here .'],
#  ['nous sommes anonymes . nous sommes legions .',
#   'we are anonymous . we are legion .'],
#  ['nous ne sommes que le fondement du chaos .',
#   'we are but the base of chaos .'],
#  ['ils sont totalement anonymes en fait .',
#   'they re completely anonymous as it were .'],
#  ['c est l autre grosse generation .', 'they re the other big generation .'],
#  ['ils sont faciles a re adapter .', 'they re easy to be re adapted .'],
#  ['les vagins m inquietent .', 'i am worried about vaginas .'],
#  ['vous dirigez aussi une societe civile .',
#   'you re also running a civil society .'],
#  ['il est toujours sur la route .', 'he s always on the road .'],
#  ['je suis un himba .', 'i m a himba .'],
#  ['je suis un himba et un namibien .', 'i m a himba and namibian .'],
#  ['ils sont photographiables . ils sont mesurables .',
#   'they re photographable . they re measurable .'],
#  ['je suis certain que nous le pouvons .', 'i m certain that we can .'],
#  ['elle dirige sa ferme .', 'she is managing her farm .'],
#  ['ils sont devant vous .', 'they are in front of you .'],
#  ['ils ont et ans .', 'they re and .'],
#  ['elle a ans .', 'she s years old .'],
#  ['elle est nue .', 'she s nude .'],
#  ['nous faisons la meme chose comme designers .',
#   'we re doing the same thing as designers .'],
#  ['nous essayons ces experiences .', 'we re trying on these experiences .'],
#  ['aujourd hui nous parlons de persuasion morale .',
#   'we are today talking about moral persuasion .'],
#  ['on prend les choses par le mauvais bout .',
#   'we re fishing at the low end .'],
#  ['j essaie de tout faire doucement .',
#   'i m trying to do everything very gently .'],
#  ['c est une bonne s ur de ans .', 'she is a year old nun .'],
#  ['nous parlons la de notre esprit .', 'we re talking about our mind .'],
#  ['on les appelle les colons volontaires .', 'they re called self settlers .'],
#  ['ils meurent de tristesse . ', 'they are dying of sadness . '],
#  ['nous travaillons egalement sur des imprimantes plus sophistiquees',
#   'we re also working on more sophisticated printers .'],
#  ['nous construisons des dispensaires dans cette circonscription .',
#   'we re building dispensaries across that constituency .'],
#  ['j essaye d ameliorer les infrastructures .',
#   'i m trying to improve infrastructure .'],
#  ['je suis bonne avec facebook .', 'i m good at facebook .'],
#  ['nous sommes a la traine .', 'we re lagging behind .'],
#  ['ils restent tres utiles .', 'they re still very useful .'],
#  ['ils ne sont simplement pas assez gros .', 'they re just not big enough .'],
#  ['ce sont des symetries de la sphere .',
#   'they are symmetries of the sphere .'],
#  ['ce sont des propriete de la loi fondamentale .',
#   'they are properties of the fundamental law .'],
#  ['c est un homme incroyable .', 'he s an amazing man .'],
#  ['ils sont mes professeurs .', 'they are my teachers .'],
#  ['je parle de l elite', 'i m talking about the elite .'],
#  ['maintenant je pense .', 'i am thinking now .'],
#  ['je suis une personne superflue .', 'i m a redundant person .'],
#  ['nous sommes une petite marque .', 'we are a smaller brand .'],
#  ['je suis le gars des animaux de compagnie .', 'i m the pet guy .'],
#  ['avocat je suis une marque d avocat .', 'i m a lawyer brand .'],
#  ['je suis tom .', 'i m tom .'],
#  ['je suis gaucher et donc je dessinne .', 'i m left handed and so i draw .'],
#  ['elle est en train de le manger .', 'she s eating him .'],
#  ['elles se controlent mieux .', 'they are more controlled .'],
#  ['c est elle l homme maintenant . ', 'she s the man now . '],
#  ['nous etions vraiment enthousiasmes .', 'we re really excited about this .'],
#  ['on essaye juste de relier les deux .',
#   'we re just trying to connect the two .'],
#  ['ils achetent maintenant des voitures .', 'they are now buying cars .'],
#  ['elles sont toujours ici .', 'they are still up here .'],
#  ['je suis un tres serieux possibiliste .',
#   'i m a very serious possibilist . '],
#  ['je ne sais pas de combien exactement .', 'i m not sure exactly how much .'],
#  ['elles sont a l arriere de notre corps .',
#   'they re in the back of our body .'],
#  ['je ne sais pas ou nous allons .', 'i m not sure where we go .'],
#  ['nous vieillissons tout simplement .', 'we re just getting older .'],
#  ['nous avons juste pris cinq secondes .',
#   'we are just taking five seconds .'],
#  ['nous jouons avec le feu .', 'we are playing with fire .'],
#  ['je collabore avec charlie brown .',
#   'i am collaborating with charlie brown .'],
#  ['il a consacre sa vie au design durable .',
#   'he s dedicated his life to sustainable design .'],
#  ['je joue pour vous .', 'i m performing for you .'],
#  ['elle a commence a chanter sa chanson .', 'she started singing her song .'],
#  ['nous sommes a ramallah a present .', 'we re in ramallah right now .'],
#  ['elles ne sont pas la pour rester .', 'they are not meant to stay .'],
#  ['nous avons faim de culture .', 'we re hungry for culture .'],
#  ['c est un peu une hippie .', 'she s a bit of a hippie .'],
#  ['je rigole .', 'i m joking .'],
#  ['je vais sauter jusqu a la .', 'i m going to jump forward here .'],
#  ['il mesure m .', 'he s foot .'],
#  ['il ne porte meme pas d epee .', 'he s not even carrying a sword .'],
#  ['ce sont des microbes . ils sont minuscules .',
#   'they re microbes . they re tiny .'],
#  ['nous sommes eux . ils sont nous .', 'we are them . they are us .'],
#  ['je pense a ton amour pour moi ', 'i am thinking of your love for me .'],
#  ['je suis dechire par ton amour pour moi .',
#   'i am torn by your love for me .'],
#  ['on me dit que tu vas partir .', 'i am told you will go from here .'],
#  ['je n en suis pas certain .', 'i m not quite sure .'],
#  ['il descend . est ce qu il vole ?', 'he is down . is he flying ?'],
#  ['il commence a faire son ascension .', 'he s starting to make his climb .'],
#  ['il est au dessus de la manche .', 'he s out over the channel .'],
#  ['il vole au dessus de la manche .',
#   'he is over the english channel and underway .'],
#  ['vous etes juste dans l element .', 'you are just in the element .'],
#  ['ils sont plus rares que le panda .',
#   'they re more rare than the panda bear .'],
#  ['ils ne vont pas mourir d hypothermie .',
#   'they re not going to die of hypothermia .'],
#  ['ils vont atteindre la terre .', 'they re going to get to land .'],
#  ['ils sont egalement imposants .', 'they re also big .'],
#  ['ce ne sont pas ces petits phoques communs .',
#   'they re not these little harbor seals .'],
#  ['ils font metres et pesent kg .', 'they are ft . long a thousand pounds .'],
#  ['je suis avec mon guide assistant suedois .',
#   'i m with my swedish assistant and guide .'],
#  ['il a tout a fait raison .', 'he s absolutely right .'],
#  ['nous sommes nes createurs .', 'we re born makers .'],
#  ['ils ne sont pas ordinaires .', 'they re not mainstream .'],
#  ['ils sont un peu radicaux .', 'they re a little bit radical .'],
#  ['je ne suis pas contre le glamour .', 'i m not against glamour .'],
#  ['et elles decollent puis s en vont .', 'they re up and they re off .'],
#  ['il est ingenieur .', 'he s an engineer .'],
#  ['vous y etes toujours avec d autres personnes .',
#   'you are always there with other people .'],
#  ['vous en voyez un bon exemple ici .',
#   'you re looking at a great example here .'],
#  ['ils sont vraiment une sorte de bouillie cosmique .',
#   'they re really a sort of cosmic mush .'],
#  ['je parle bien entendu des organismes vivants .',
#   'i m talking of course about living organisms .'],
#  ['nous sommes d enormes paquets de produits chimiques .',
#   'we are huge packages of chemicals .'],
#  ['ils sont tout simplement trop paresseux .', 'they re just too lazy .'],
#  ['ils sont vraiment furieux .', 'they re really mad .'],
#  ['nous sommes they might be giants .', 'we are they might be giants .'],
#  ['vous etes en direct .', 'you re live .'],
#  ['j essaye de gagner du temps .', 'i m trying to buy time .'],
#  ['nous sommes les histoires que nous nous racontons .',
#   'we are the stories we tell ourselves .'],
#  ['c est pour elles que nous sommes nes .', 'we re born for them .'],
#  ['nous sommes nes pour resoudre des problemes .',
#   'we re born problem solvers .'],
#  ['ils apprennent qui ils sont .', 'they re learning who they are .'],
#  ['il ne pourra pas .', 'they re not .'],
#  ['je n invente rien .', 'i am not making this up .'],
#  ['je ne prend pas parti .', 'i m not taking sides .'],
#  ['ce sont les choses blanches floues elliptiques ici .',
#   'they re the white fuzzy elliptical things here .'],
#  ['vous etes assis sur des chaises .', 'you re sitting on chairs .'],
#  ['elles sont inanimees elle ne sont pas vivantes .',
#   'they re inanimate they re not alive .'],
#  ['nous sommes presses . cinq ans .', 'we are in a hurry . five years .'],
#  ['on ne parle pas d innovation exclusive .',
#   'you re not talking exclusive innovation .'],
#  ['on parle d innovation inclusive .',
#   'you re talking about inclusive innovation .'],
#  ['ils ne sont pas disponibles en afrique .',
#   'they re not available in africa .'],
#  ['je m imagine toujours dans des situations differentes .',
#   'i m always imagining myself in different situations .'],
#  ['je m imagine en tant que machine .', 'i m imagining myself as a machine .'],
#  ['je suis spectroscopiste .', 'i m a spectroscopist .'],
#  ['je suis une chercheuse en sciences humaines .',
#   'i m a qualitative researcher .'],
#  ['vous etes probablement familier avec le nike systeme .',
#   'you re probably familiar with the nike system .'],
#  ['je vais me connecter .', 'i m going to log in .'],
#  ['nous n allons pas faire cela .', 'we re simply not going to do that .'],
#  ['nous en sommes a un tournant en fait .',
#   'we re kind of at a tipping point .'],
#  ['je suis influence .', 'i m biased .'],
#  ['on ameliore les ventes de .', 'you re percent better at sales .'],
#  ['c est juste un petit garcon .', 'he s just a little boy .'],
#  ['ce sont des exercices de memoire glorifies .',
#   'they re glorified drill and practice .'],
#  ['nous sommes les vieilles machines .', 'we are the old machines .'],
#  ['il me rend malade .', 'i m sick of it .'],
#  ['c est le gars sur la gauche .', 'he s the dude on the left .'],
#  ['nous allons vivre d extraordinaires decennies .',
#   'we are living into extraordinary decades ahead .'],
#  ['ils travaillent pour plusieurs agences .',
#   'they re from multiple agencies .'],
#  ['ils sont probablement plus chers .',
#   'they re likely to be more expensive .'],
#  ['juste une idee .', 'i m just saying .'],
#  ['on nous teste .', 'we re tested .'],
#  ['ils sont censes etre enfermes ', 'they are supposed to be locked up .'],
#  ['c est un ado de ans .', 'he s a year old .'],
#  ['ils sont juste coupes a differentes hauteurs .',
#   'they re just chopped at different heights .'],
#  ['ce sont l art et l education parentale .',
#   'they are the arts and parenting .'],
#  ['il fait une journee . ', 'he s like a day . '],
#  ['il gagne super bien sa vie .', 'he s making a great living .'],
#  ['nous sommes branches nous sommes connectes .',
#   'we re plugged in we re connected .'],
#  ['je plaisante . je ne plaisante pas .', 'i m kidding . i m not kidding .'],
#  ['je plaisante .', 'i m kidding .'],
#  ['on les appelle le cchr .', 'they re called the cchr .'],
#  ['je n ai pas de troubles mentaux . ', 'i m not mentally ill . '],
#  ['nous commencons a construire nous memes la resilience .',
#   'we re starting to build resilience ourselves .'],
#  ['ce sont comme des photographies du temps .',
#   'they re like a snapshot in time .'],
#  ['nous sommes entierement recyclables .', 'we are all totally recyclable .'],
#  ['je suis dans un train .', 'i m sitting on a train .'],
#  ['je suis assis sur une chaise .', 'i m sitting on a chair .'],
#  ['je suis heureux que l univers soit vain .',
#   'i m glad the universe is pointless .'],
#  ['nous sommes la pour la connaissance .', 'we are here for knowledge .'],
#  ['vous etes indien egyptien italien americain .',
#   'you re an indian egyptian italian american .'],
#  ['elle est lyceenne .', 'she s a high school student .'],
#  ['elle a sauve fillettes de l excision .',
#   'she saved girls from being cut .'],
#  ['d habitude j ai un micro a pied .', 'i m used to a stationary mic .'],
#  ['nous sommes au milieu du processus .',
#   'we re in the middle of the process .'],
#  ['on interagit avec l outil de divertissement .',
#   'we are interacting with our entertainment .'],
#  ['il a plus de temps .', 'he s out of time .'],
#  ['nous sommes des creatures biologiques .', 'we re biological creatures .'],
#  ['nous allons faire beaucoup d erreurs .',
#   'we re going to make lots of errors .'],
#  ['nous allons le faire c est sur .', 'we are definitely .'],
#  ['ils faconnent la maniere dont nous consommons .',
#   'they are shaping the way we consume .'],
#  ['ils faconnent nos desirs memes .', 'they are shaping our very desires .'],
#  ['on leur prete des pouvoirs magiques .',
#   'they are believed to have magical powers .'],
#  ['nous sommes a et cela augmente .', 'we are at and climbing .'],
#  ['ce sont des etats qui ont echoue .', 'they re failed states .'],
#  ['elles ne sont pas legalement responsables .',
#   'they re not legally liable .'],
#  ['desolee .', 'i m sorry .'],
#  ['je vais vous parler de religion .', 'i m going to talk about religion .'],
#  ['elles sont tres utiles a des fins educatives .',
#   'they are quite useful for educational purposes .'],
#  ['nous sommes ici en haut .', 'we are here on top .'],
#  ['elle se fait des soucis .', 'she s worried .'],
#  ['ils utilisent leurs mains .', 'they re using their hands .'],
#  ['ils sont partout .', 'they re everywhere .'],
#  ['ils ne sont pas riches du tout .', 'they re not rich at all .'],
#  ['je suis quelqu un de tres chanceux .', 'i m a very lucky person .'],
#  ['environ . pays sont generes chaque annee .',
#   'we re generating about . states per year .'],
#  ['nous sommes tous des menteurs .', 'we re all liars .'],
#  ['nous sommes fondamentalement contre le mensonge .',
#   'we re essentially against lying .'],
#  ['nous allons commencer avec le discours ',
#   'we re going to start with speech .'],
#  ['je vais me repeter .', 'i m going to say this again .'],
#  ['elle sera enthousiaste .', 'they re going to be enthusiastic .'],
#  ['ce ne sont pas des preuves de mensonge .',
#   'they re not proof of deception .'],
#  ['ce sont des drapeaux rouges .', 'they re red flags .'],
#  ['nous sommes des etres humains .', 'we re human beings .'],
#  ['il pleurniche .', 'he s sniveling .'],
#  ['ils sont plutot sympas .', 'they re pretty cool .'],
#  ['c est une vraie artiste .', 'she s an actual you know artist .'],
#  ['je ne plaisante pas .', 'i m not kidding .'],
#  ['ils attendent d etre circoncis .', 'they re waiting to be circumcised .'],
#  ['ils sont comme des facilitateurs du systeme .',
#   'they are like capacitors of the system .'],
#  ['on ne les connait pas bien .', 'they re very little understood .'],
#  ['on monte sur une de ces colonnes .',
#   'we re moving up one of these pillars .'],
#  ['ce sont des endroits comme celui ci .', 'they re places like this .'],
#  ['c est un revolutionnaire complet .', 'he s a complete revolutionary .'],
#  ['je parle de vous caroline du nord .',
#   'i m looking at you north carolina .'],
#  ['nous sommes les sujets de nos propres vies .',
#   'we are the subjects of our own lives .'],
#  ['desole pour ca .', 'i m sorry for this .'],
#  ['vous entendez la vie d une personne .', 'you re hearing a person s life .'],
#  ['je suis une decoupeuse de papier', 'i am a papercutter .'],
#  ['il s agit plutot de nos identites sociales .',
#   'they are more our social identities .'],
#  ['simplement trop bizarre .', 'she s simply too strange .'],
#  ['je suis meritocratique un point c est tout .',
#   'i am a meritocrat in that sense .'],
#  ['on est tres ouvert aux conseils .', 'we are highly open to suggestion .'],
#  ['vous etes immerges dans le liquide .', 'you re immersed in the liquid .'],
#  ['il est pique .', 'he s stung .'],
#  ['il a developpe une cuisine tres avant gardiste ',
#   'he s developed a very avant garde cuisine .'],
#  ['le maniement est plutot complexe .', 'he s a cheeky little devil .'],
#  ['je ne suis pas une exception .', 'i m no exception .'],
#  ['je parle d esclavage reel .', 'i m talking about real slavery .'],
# ...
#  ['on y est presque . oh mon dieu !', 'we re nearly there . oh my god !'],
#  ['vous etes un monstre de la nature .',
#   'you re like a freak ass of nature .'],
#  ['elle ne prend pas de risque .', 'she s not taking any chances .'],
#  ['j essaye d etre sage la .', 'i m trying to be good here .'],
#  ['on les appelle les granny cloud .', 'they re called the granny cloud .'],
#  ['je m interesse a ces idees de repetition .',
#   'i m interested in these ideas of repetition .'],
#  ['elles sont toutes differentes .', 'they re all different .'],
#  ['ils eprouvent la ce caractere primitif .',
#   'they re experiencing that rawness there .'],
#  ['ils protestent toujours .', 'they are still protesting .'],
#  ['nous nous dirigeons vers une identite en ligne .',
#   'we re moving towards persistent identity .'],
#  ['ce sont vraiment des disciplines s urs .',
#   'they re really kindred disciplines .'],
#  ['c est la plus perdante des perdantes .', 'she s under the underdogs .'],
#  ['nous ne sommes pas rapides .', 'we re not fast .'],
#  ['il est tres mechant leo .', 'he s very bad leo .'],
#  ['c est un monstre effrayant .', 'he s a scary monster .'],
#  ['ca va motiver cet enfant .', 'you re getting that kid turned on .'],
#  ['ils experimentent avec l ouverture .',
#   'they are experimenting with openness .'],
#  ['vous pouvez tous nous rejoindre .', 'you re all welcome to join .'],
#  ['nous cherchons plus .', 'we re looking for something more .'],
#  ['j ai ans maintenant .', 'i m years old right now .'],
#  ['nous allons repandre le message .', 'we are going to spread the message .'],
#  ['il est d haiti et a le sida ', 'he s from haiti and he has aids .'],
#  ['elle disait soit bon envers tes amis .',
#   'she said be good to your friends .'],
#  ['j ai ans j ai toujours le cheque .', 'i m still have the check .'],
#  ['je suis en mode divertir et epater .', 'i m in entertain amaze mode .'],
#  ['ils reflechissent aux memes choses .',
#   'they re thinking about the same things .'],
#  ['on est fermes completement .', 'we are totally closed .'],
#  ['je suis desole .', 'i m so sorry .'],
#  ['je suis tellement desole . non non .', 'i m so sorry . no no .'],
#  ['on lui a rendu hommage avec une statue .',
#   'he s been honored with a statue now .'],
#  ['je vais parler des dinosaures .', 'i m going to talk about dinosaurs .'],
#  ['ils ont tous disparus .', 'they re all gone .'],
#  ['ils sont tous grands .', 'they re all big .'],
#  ['on en prend vraiment bien soin .', 'they re very well taken care of .'],
#  ['cependant je pense a wael ghonim .',
#   'i m thinking of wael ghonim though .'],
#  ['ils se basent sur les cellules .', 'they re cell oriented .'],
#  ['elles ne sont pas bonnes non plus .', 'they re no good either .'],
#  ['d ailleurs ils nous en apportent encore .',
#   'they re not finished giving yet . '],
#  ['il n avait plus de jambes ', 'he s got no legs .'],
#  ['plus de bras .', 'he s got no arms .'],
#  ['je fais m et je suis gras .', 'i m six foot one and fat .'],
#  ['je lui fais ouais ? ', 'i m like yeah ? '],
#  ['ils ne sont pas tres animes .', 'they re not very animated .'],
#  ['nous sommes tous dans le meme bateau .', 'we re all in this together .'],
#  ['nous recevons toujours une dose d uva .',
#   'we re still getting a dose of uva .'],
#  ['vous etes le produit de l evolution .',
#   'you are the products of evolution .'],
#  ['elle souffre depuis des annees .', 'she s been suffering for years .'],
#  ['nous ne sommes pas seuls .', 'we are not alone .'],
#  ['elles sont tres importante dans les marees noires .',
#   'they re very important in oil spills .'],
#  ['je suis sans defenses . ', 'i am helpless over this . '],
#  ['vous pouvez les trouver sur newamerica .net .',
#   'they re up at newamerica .net .'],
#  ['nous avons du retard .', 'we are running late .'],
#  ['je vais enchainer un peu ici .', 'i m going to segue a little here .'],
#  ['je fais ce que je peux .', 'i m just doing what i can here .'],
#  ['vous allez trop lentement .', 'you re going too slow .'],
#  ['c est fait a partir de cremations .', 'they re made from cremains . '],
#  ['il est tres exigeant .', 'he s a very demanding person .'],
#  ['je vais vous parler de la conscience .',
#   'i m going to talk about consciousness .'],
#  ['ils ont trois ans .', 'they re three .'],
#  ['tu es trop jeune pour aider .', 'you re much too young to help .'],
#  ['vous etes l adulte .', 'you re the adult .'],
#  ['ce sont des etres humains tout comme nous .',
#   'they are human beings just like us .'],
#  ['elle a dit oui monsieur . ', 'she said yes sir . '],
#  ['je suis avec toi mon gars . ', 'i m going with you man . '],
#  ['je vais parler maintenant de la faisabilite .',
#   'i m now going to talk about feasibility .'],
#  ['nous sommes plutot en securite ici .', 'we re pretty safe here .'],
#  ['ils le decouvrent seulement .', 'they are just discovering .'],
#  ['ils travaillent tous seuls dans leur coin !',
#   'they are just going alone !'],
#  ['vous etes indisciplines . ', 'you are undisciplined . '],
#  ['passons maintenant a la saison seche .',
#   'we re going to the dry season now .'],
#  ['ils sont totalement naturels .', 'they re completely natural .'],
#  ['ce sont les seules dangereuses .',
#   'they re the only ones that are dangerous .'],
#  ['ils n apprecient meme pas le spectacle .',
#   'they re not even enjoying the show .'],
#  ['je suis croyant .', 'i m a believer .'],
#  ['je parle du petrole de l opep .', 'i m talking about opec oil .'],
#  ['c est termine .', 'they re over .'],
#  ['au gaz naturel .', 'we re headed to natural gas .'],
#  ['je reviens a present a la theorie .', 'i m back to theorist again .'],
#  ['on deborde de gaz naturel .', 'we are overwhelmed with natural gas .'],
#  ['je ne suis pas producteur de gaz naturel .',
#   'i m not a big natural gas producer .'],
#  ['nous sommes en ', 'we re in .'],
#  ['ils sont completement differents les uns des autres .',
#   'they are completely different from each other .'],
#  ['vous vous deplacez en quelque sorte .',
#   'you re just kind of moving around .'],
#  ['je m inspire beaucoup beaucoup beaucoup des films .',
#   'i m very very very inspired by movies .'],
#  ['ils sont encordes ici .', 'they re on fixed ropes here .'],
#  ['il perd de l energie .', 'he s running out of energy .'],
#  ['il est en train de mourir .', 'he s dying .'],
#  ['il me repond oui deborah ? ', 'he s like yes deborah ? '],
#  ['c est un gars costaud .', 'he s a big guy .'],
#  ['je travaille deja . ', 'i m working already . '],
#  ['ca va aller . ', 'i m going to be all right . '],
#  ['nous allons aussi vite que possible .', 'we re going as fast as we can .'],
#  ['ils sont dependants des autres .', 'they are dependent on others .'],
#  ['il est de retour a la vie normale .', 'he s back to his normal life .'],
#  ['c est une creatrice de mode italienne .',
#   'she s an italian fashion designer .'],
#  ['elle l examine sous tous les angles .', 'she s turning it inside out .'],
#  ['ils sont malins .', 'they re smart .'],
#  ['il est malin . il est intelligent .', 'he s smart he s smart .'],
#  ['j ai peur de ce que je vois .', 'i m afraid by what i see .'],
#  ['ils sont faits dans le bon ordre .', 'they are made in the right order .'],
#  ['elles accomplissent le puja .', 'they are performing puja .'],
#  ['cela fait sept ans que je tiens bon .', 'i m sustaining on seventh year .'],
#  ['je fais quelque chose de serieux .', 'i m doing something serious .'],
#  ['j en suis convaincu .', 'i m convinced of it .'],
#  ['elle etait dans sa chambre .', 'she stayed in her room .'],
#  ['ils sont tres bon marche tres rustiques .',
#   'they re inexpensive really rugged .'],
#  ['nous avons l allemagne qui ne ratifie pas',
#   'we are germany is not ratifying .'],
#  ['je ne me connecte pas aux tableaux .', 'i m not connecting to them .'],
#  ['je souffre de fatigue de galerie .',
#   'i m suffering from gallery fatigue .'],
#  ['il ne me regardera jamais .', 'he s never going to look at me .'],
#  ['j essaye aussi de proteger mon visage .',
#   'i m trying to protect my face too .'],
#  ['on les achete dans les video clubs .', 'they are bought in video shops .'],
#  ['nous travaillons pour lui .', 'we re doing some work for him .'],
#  ['nous ne les reconstruisons pas encore assez bien .',
#   'we re still not reconstructing them well enough .'],
#  ['ils ne seront pas intelligents .', 'they re not going to be smart .'],
#  ['j ajoute ca a mon temps .', 'i m adding that to my time .'],
#  ['je plaisante .', 'i m just kidding .'],
#  ['on ne parle pas du connecticut .', 'we re not talking about connecticut .'],
#  ['je n en suis pas fan . ', 'i m not a fan . '],
#  ['je parle de la mort .', 'i m talking about dying .'],
#  ['je ne suis pas geriatre .', 'i m not a geriatrician .'],
#  ['vous aurez besoin d auxiliaires de vie .',
#   'you re going to need caregivers .'],
#  ['ils sont au debut des chaines alimentaires .',
#   'they re at the start of food chains .'],
#  ['vous en mangez au moins grammes par an .',
#   'you re eating at least grams per year .'],
#  ['nous le faisons meme expres', 'we re even doing this on purpose .'],
#  ['nous ne prenons pas encore le bonus .', 'we re not taking the bonus yet .'],
#  ['ce sont des mets raffines .', 'they are delicacies .'],
#  ['ils sont tout simplement hors de prix .',
#   'they are just incredibly expensive .'],
#  ['ils datent de plus de ans .', 'they are over years old .'],
#  ['dans les faits nous reinventons la roue ici !',
#   'we are literally re inventing the wheel here .'],
#  ['elle a ans .', 'she is years old .'],
#  ['c etait un personnage intimidant tout de meme .',
#   'he s just a rather intimidating figure .'],
#  ['elles sont aussi en silicone', 'they re also silicon .'],
#  ['ce sont des programmes obscurs et bizarres .',
#   'they re obscure weird programs .'],
#  ['nous decollons .', 'we re taking off .'],
#  ['nous sommes pile a ce moment de transition .',
#   'we re right at that point of transition .'],
#  ['vous etes en chemin .', 'you re on your way to the theater .'],
#  ['ca m interesse .', 'i m interested .'],
#  ['il ne prend pas soin de ses troupes .',
#   'he s not taking care of his troops .'],
#  ['j ai ou ans je ne sais plus .', 'i am or . i don t remember .'],
#  ['vous n etes pas juge .', 'you are not on trial .'],
#  ['il construit cette immense place en beton .',
#   'he s building this huge concrete place .'],
#  ['ils en parlent encore .', 'they re still talking about it .'],
#  ['on ne va pas defier la gravite .', 'you re not going to defy gravity .'],
#  ['rw je vais le faire pour vous !', 'i m going to make it for you !'],
#  ['je suis un eboueur .', 'i m a garbage man .'],
#  ['vous avez les smokings les bouquets .',
#   'you re seeing the tuxedos the bouquets .'],
#  ['je vais juste vous donner dollars .', 'i m just going to give you bucks .'],
#  ['nous sommes juste concus differemment .', 'we re just built differently .'],
#  ['ce sont les materiaux du siecle dernier .',
#   'they re the materials of the last century .'],
#  ['ils sont notre famille . ', 'they are our family . '],
#  ['on est tous des fils dessus .', 'we re all strands in it .'],
#  ['ensemble nous ne sommes qu une seule personne .',
#   'we are one people together .'],
#  ['au combat jour et nuit .', 'i m on a fight day and night .'],
#  ['je suis juste habituee a cette histoire la .',
#   'i m just so used to that story .'],
#  ['ce sont des pays d amerique latine .', 'they re latin american .'],
#  ['c est l endroit le plus heureux .', 'they are the happiest place .'],
#  ['c est mon grand pere .', 'he is my grandfather .'],
#  ['elles ont une immense imagination .', 'they re highly imaginative .'],
#  ['ce sont deux types de reflexions efficaces .',
#   'they re both perfectly good ways of thinking .'],
#  ['et se repandent dans le monde entier .',
#   'they are seeping around the world .'],
#  ['je mise ma carriere la dessus .', 'i m betting my career on this .'],
#  ['aujourd hui elle s appelle kickstart .', 'they re now called kickstart .'],
#  ['ils ne sont plus deranges .', 'they are not disturbed anymore .'],
#  ['je suis professeur je dois vous questionner !',
#   'i m a professor i must quiz you .'],
#  ['je suis desole de dire ca .', 'i m so sorry to say that .'],
#  ['elle disait change de metier . ', 'she said change your profession . '],
#  ['je ne suis pas si genereuse .', 'i am not that caring .'],
#  ['je surveille ceux qui me surveillent .',
#   'i m watching who s watching me .'],
#  ['je n utilise pas de donnees hypothetiques .',
#   'i m not using any hypothetical data .'],
#  ['ils sont tous la meme ponderation .', 'they re all weighted equally .'],
#  ['je vais commencer tres tres simplement .',
#   'i m going to start really really simply .'],
#  ['je ne leur demande pas de copier exactement .',
#   'i m not asking them to copy exactly .'],
#  ['je suis daltonien .', 'i m colorblind .'],
#  ['nous sommes tous intimement lies . .', 'we are all intimately connected .'],
#  ['on parle de television populaire .', 'we re talking about popular tv .'],
#  ['je suis desempare .', 'i m totally clueless .'],
#  ['ils recherchent tous leur escalier .',
#   'they re all searching for their staircase .'],
#  ['on termine .', 'we are wrapping up .'],
#  ['je ne suis simplement pas convaincu du progres .',
#   'i m just not sure this is improvement .'],
#  ['je suis un fervent supporter des organisations locales .',
#   'i m a big fan of grassroots organizations .'],
#  ['nous sommes tous assez semblables .', 'we re all pretty much the same .'],
#  ['c est une tres gentille jeune fille noire .',
#   'she s a very nice young black girl .'],
#  ['je suis dominicaine et americaine .', 'i am dominican american .'],
#  ['je suis lesbienne . ', 'i am lesbian . '],
#  ['je suis originaire de jordanie .', 'i am originally from jordan .'],
#  ['je suis vraiment desole .', 'i m really sorry .'],
#  ['ils sont differents de vous et moi .',
#   'they re different from me and you .'],
#  ['ils sont assez beaux .', 'they re quite beautiful .'],
#  ['nous ne sommes pas les seuls .', 'we re not the only ones .'],
#  ['en post bac mitchell seligson',
#   'he s an undergrad professor mitchell seligson .'],
#  ['il est medecin la bas .', 'he s a doctor there .'],
#  ['je viens d un pays appele serbie .',
#   'i am coming from a country called serbia .'],
#  ['je suis une texane de cinquieme generation .',
#   'i m a fifth generation texan .'],
#  ['je ne suis pas nee chercheuse en vulnerabilite .',
#   'i am not a natural vulnerability researcher .'],
#  ['tu n es pas assez bonne .', 'you re not good enough .'],
#  ['vous faites tous partie de l art aussi .',
#   'you re all part of the artwork too .'],
#  ['ils s entraident pour atteindre ce but .',
#   'they re helping each other do it .'],
#  ['ils sont d habitude enterres dans le sol .',
#   'they re typically buried in the ground .'],
#  ['je suis la mere de zacharias moussaoui .',
#   'i am the mother of zacarias moussaoui .'],
#  ['nous sommes dans la belle ville d oxford .',
#   'we re in the fine city of oxford .'],
#  ['nous sommes desormais interdependants .', 'we are now interdependent .'],
#  ['nous sommes desormais tous tres tres profondement lies .',
#   'we are all now deeply deeply deeply interconnected .'],
#  ['elle commence sa journee en soulevant des alteres .',
#   'she starts her day with lifting weights .'],
#  ['vous etes dans cette extension du corps .',
#   'you re in this extended body .'],
#  ['elle est veuve et enceinte .', 'she s pregnant and a widow .'],
#  ['elles sont parmi les plus pauvres .', 'they are the poorest of the poor .'],
#  ['ils ne sont pas du tout strategiques .',
#   'they re not being really strategic at all .'],
#  ['ils sont choisis aleatoirement .', 'they re just choosing randomly .'],
#  ['ils sont poilus puants rapides et forts .',
#   'they re hairy smelly fast and strong .'],
#  ['ils sont aussi obsedes par le status .',
#   'they re also very obsessed with status .'],
#  ['ils vont appuyer a gauche ou a droite .',
#   'they re going to press left or right .'],
#  ['je vais vous parler de rome .', 'i m going to talk about rome .'],
#  ['nous sommes noyes sous l information .', 'we are drowning in news .'],
#  ['ce que vous voyez c est un littoral .', 'you are looking at a shoreline .'],
#  ['je suis cineaste .', 'i m a filmmaker .'],
#  ...]

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A `Sequence to Sequence network <http://arxiv.org/abs/1409.3215>`__, or
# seq2seq network, or `Encoder Decoder
# network <https://arxiv.org/pdf/1406.1078v3.pdf>`__, is a model
# consisting of two RNNs called the encoder and decoder. The encoder reads
# an input sequence and outputs a single vector, and the decoder reads
# that vector to produce an output sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence "Je ne suis pas le chat noir" → "I am not the
# black cat". Most of the words in the input sentence have a direct
# translation in the output sentence, but are in slightly different
# orders, e.g. "chat noir" and "black cat". Because of the "ne/pas"
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the "meaning" of the input sequence into a single
# vector — a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# .. figure:: /_static/img/seq-seq-images/encoder-network.png
#    :alt:

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# The Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ^^^^^^^^^^^^^^
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string ``<SOS>``
# token, and the first hidden state is the context vector (the encoder's
# last hidden state).
#
# .. figure:: /_static/img/seq-seq-images/decoder-network.png
#    :alt:

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we'll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# ^^^^^^^^^^^^^^^^^
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# .. figure:: https://i.imgur.com/1152PYf.png
#    :alt:
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# .. figure:: /_static/img/seq-seq-images/attention-decoder-network.png
#    :alt:

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>There are other forms of attention that work around the length
#   limitation by using a relative position approach. Read about "local
#   attention" in `Effective Approaches to Attention-based Neural Machine
#   Translation <https://arxiv.org/abs/1508.04025>`__.</p></div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# "Teacher forcing" is the concept of using the real target outputs as
# each next input, instead of using the decoder's guess as the next input.
# Using teacher forcing causes it to converge faster but `when the trained
# network is exploited, it may exhibit
# instability <http://minds.jacobs-university.de/sites/default/files/uploads/papers/ESNTutorialRev.pdf>`__.
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation -
# intuitively it has learned to represent the output grammar and can "pick
# up" the meaning once the teacher tells it the first few words, but it
# has not properly learned how to create the sentence from the translation
# in the first place.
#
# Because of the freedom PyTorch's autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# ``teacher_forcing_ratio`` up to use more of it.

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True #if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            # decoder_output, decoder_hidden, decoder_attention = decoder(
            #     decoder_input, decoder_hidden, encoder_outputs)
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            # decoder_output, decoder_hidden, decoder_attention = decoder(
            #     decoder_input, decoder_hidden, encoder_outputs)
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -  Start a timer
# -  Initialize optimizers and criterion
# -  Create set of training pairs
# -  Start empty losses array for plotting
#
# Then we call ``train`` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ----------------
#
# Plotting is done with matplotlib, using the array of loss values
# ``plot_losses`` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            # decoder_output, decoder_hidden, decoder_attention = decoder(
            #     decoder_input, decoder_hidden, encoder_outputs)
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)                                   
            # decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words#, decoder_attentions[:di + 1]

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        # output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_words = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we'll get some
# reasonable results.
#
# .. Note::
#    If you run this notebook you can train, interrupt the kernel,
#    evaluate, and continue training later. Comment out the lines where the
#    encoder and decoder are initialized and run ``trainIters`` again.

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
# attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
# trainIters(encoder1, attn_decoder1, 75000, print_every=5000)

attn_decoder1 = DecoderRNN(hidden_size, output_lang.n_words).to(device)
trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
# Out:
# 1m 10s (- 16m 20s) (5000 6%) 2.8158
# 2m 15s (- 14m 38s) (10000 13%) 1.3824
# 3m 20s (- 13m 22s) (15000 20%) 0.5760
# 4m 26s (- 12m 12s) (20000 26%) 0.2155
# 5m 31s (- 11m 3s) (25000 33%) 0.0835
# 6m 36s (- 9m 55s) (30000 40%) 0.0452
# 7m 41s (- 8m 47s) (35000 46%) 0.0290
# 8m 46s (- 7m 40s) (40000 53%) 0.0218
# 9m 51s (- 6m 34s) (45000 60%) 0.0169
# 10m 55s (- 5m 27s) (50000 66%) 0.0154
# 11m 59s (- 4m 21s) (55000 73%) 0.0133
# 13m 4s (- 3m 16s) (60000 80%) 0.0107
# 14m 8s (- 2m 10s) (65000 86%) 0.0101
# 15m 13s (- 1m 5s) (70000 93%) 0.0100
# 16m 17s (- 0m 0s) (75000 100%) 0.0088

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > nous ne sommes la que pour le decor .
# = we are for decorative purposes only .
# < we are for decorative purposes only . <EOS>
#
# > elles sont menacees a cause du changement climatique .
# = they re under threat because of changing climate .
# < they re under threat because of changing climate . <EOS>
#
# > je vais faire une prediction .
# = i m going to make a prediction .
# < i m going to make a prediction . <EOS>
#
# > nous sommes nes pour faire la difference .
# = we re born to make a difference .
# < we re born to make a difference . <EOS>
#
# > nous sommes tous une famille .
# = we re all one family .
# < we re all one family . <EOS>
#
# > ce seront les plus resistants .
# = they re going to be the tough ones .
# < they re going to be the tough ones . <EOS>
#
# > je suis l un des organisateurs de tedxkibera .
# = i m one of the organizers of tedxkibera .
# < i m one of the organizers of tedxkibera . <EOS>
#
# > elle a six mois .
# = she s a six monther .
# < she s a six monther . <EOS>
#
# > il gagne super bien sa vie .
# = he s making a great living .
# < he s making a great living . <EOS>
#
# > ils sont retournes a philadelphie .
# = they re back in philadelphia .
# < they re back in philadelphia . <EOS>

# %% [markdown]
# Visualizing Attention
# ---------------------
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run ``plt.matshow(attentions)`` to see attention output
# displayed as a matrix, with the columns being input steps and rows being
# output steps:

# %%
output_words, attentions = evaluate(
    encoder1, attn_decoder1, "je suis trop froid .")
plt.matshow(attentions.numpy())

# %% [markdown]
# For a better viewing experience we will do the extra work of adding axes
# and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)


evaluateAndShowAttention("elle a cinq ans de moins que moi .")

evaluateAndShowAttention("elle est trop petit .")

evaluateAndShowAttention("je ne crains pas de mourir .")

evaluateAndShowAttention("c est un jeune directeur plein de talent .")
# Out:
# input = elle a cinq ans de moins que moi .
# output = he m not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are
# input = elle est trop petit .
# output = we are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are
# input = je ne crains pas de mourir .
# output = she are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are
# input = c est un jeune directeur plein de talent .
# output = we are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are not are

# %% [markdown]
# Exercises
# =========
#
# -  Try with a different dataset
#
#    -  Another language pair
#    -  Human → Machine (e.g. IOT commands)
#    -  Chat → Response
#    -  Question → Answer
#
# -  Replace the embeddings with pre-trained word embeddings such as word2vec or
#    GloVe
# -  Try with more layers, more hidden units, and more sentences. Compare
#    the training time and results.
# -  If you use a translation file where pairs have two of the same phrase
#    (``I am test \t I am test``), you can use this as an autoencoder. Try
#    this:
#
#    -  Train as an autoencoder
#    -  Save only the Encoder network
#    -  Train a new Decoder for translation from there
